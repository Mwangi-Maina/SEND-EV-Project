# %% [markdown]
# # Project Summary
#
# This project recreated an energy analysis workflow using SEND campus power data and Solcast weather data.
#
# The aim was to clean the raw data, estimate expected solar generation, repair missing solar generation, create machine learning features, and train models to predict solar PV generation and electricity consumption.

# %%
# Check main outputs.
from pathlib import Path
import os

def find_project_root():
    current = Path.cwd()

    for folder in [current] + list(current.parents):
        if (folder / "Data").exists() and (folder / "Notebooks").exists():
            return folder

    raise FileNotFoundError("Could not find project root. Make sure Data and Notebooks folders exist.")

project_folder = find_project_root()
os.chdir(project_folder)

files = [
    "Data/DEOP/2022_DEOP.csv",
    "Data/DEOP/2022_DEOP_Interp.csv",
    "Data/DEOP/2022_DEOP_Repaired.csv",
    "Data/DEOP/2022_Expected.csv",
    "Data/DEOP/2023_DEOP.csv",
    "Data/DEOP/2023_DEOP_Interp.csv",
    "Data/DEOP/2023_DEOP_Repaired.csv",
    "Data/DEOP/2023_Expected.csv",
    "Data/Solcast/Solcast_2022.csv",
    "Data/Solcast/Solcast_2023.csv",
]

for file in files:
    print(file, "FOUND" if os.path.exists(file) else "MISSING")
# Out:
# Data/DEOP/2022_DEOP.csv FOUND
# Data/DEOP/2022_DEOP_Interp.csv FOUND
# Data/DEOP/2022_DEOP_Repaired.csv FOUND
# Data/DEOP/2022_Expected.csv FOUND
# Data/DEOP/2023_DEOP.csv FOUND
# Data/DEOP/2023_DEOP_Interp.csv FOUND
# Data/DEOP/2023_DEOP_Repaired.csv FOUND
# Data/DEOP/2023_Expected.csv FOUND
# Data/Solcast/Solcast_2022.csv FOUND
# Data/Solcast/Solcast_2023.csv FOUND

# %% [markdown]
# ## Data Used
#
# The project used two main data sources:
#
# 1. DEOP campus power data
#    This included electricity consumption, wind generation, and solar PV generation at 5-minute intervals.
#
# 2. Solcast weather and irradiance data
#    This included weather variables such as air temperature, irradiance, cloud opacity, snow depth, and wind speed.
#
# The DEOP data was stored in monthly raw files, while the Solcast data was stored in one larger file covering 2022 and 2023.

# %% [markdown]
# ## Workflow
#
# Raw DEOP data
# -> cleaned DEOP data
#
# Raw Solcast data
# -> cleaned Solcast data
# -> expected solar generation
#
# Expected solar + actual solar
# -> repaired solar generation
#
# Cleaned data + weather data
# -> model features
#
# Model features
# -> XGBoost solar and consumption models
#
# Models
# -> predictions, accuracy scores, graphs, and feature importance

# %% [markdown]
# ## Data Cleaning
#
# The DEOP data was cleaned by:
#
# - reading each monthly file,
# - combining months into one yearly dataset,
# - converting date and time columns into a DateTime column,
# - converting timestamps from UK time,
# - removing impossible negative power values,
# - filling missing timestamps,
# - and interpolating missing electricity consumption values.
#
# The main cleaned files were:
#
# - `2022_DEOP_Interp.csv`
# - `2023_DEOP_Interp.csv`

# %% [markdown]
# ## Expected Solar Generation
#
# Expected solar generation was calculated using Solcast irradiance data.
#
# The calculation used:
#
# - global tilted irradiance,
# - total PV panel area,
# - number of PV panels,
# - and yearly solar efficiency.
#
# This produced expected solar files:
#
# - `2022_Expected.csv`
# - `2023_Expected.csv`

# %% [markdown]
# ## Missing Generation Repair
#
# Some days had very low actual solar or wind generation compared with what
# their respective weather data implied (expected solar generation for the PV
# column, and an empirical wind-speed-to-generation curve for the wind column).
#
# These days were treated as missing or broken sensor days. The repair
# estimates generation for that column only on those problem days, leaving
# consumption and the other generation column untouched.
#
# The repaired files were:
#
# - `2022_DEOP_Repaired.csv`
# - `2023_DEOP_Repaired.csv`

# %% [markdown]
# ## Feature Engineering
#
# Two feature sets were created.
# For consumption prediction, the features included:
# - air temperature,
# - heating demand,
# - cooling demand,
# - hour,
# - day of week,
# - month,
# - holiday indicators,
# - term-time indicators,
# - lagged consumption,
# - and rolling 7-day baseline consumption.
# For solar prediction, the features included:
# - irradiance,
# - cloud opacity,
# - snow depth,
# - month,
# - day of month,
# - previous solar generation lags,
# - solar volatility,
# - irradiance volatility,
# - previous daily solar peak,
# - and time-of-day solar potential.

# %% [markdown]
# ## Modelling
# Two XGBoost models were created:
# 1. Solar PV model
#    This predicted solar PV generation.
# 2. Consumption model
#    This predicted electricity consumption.
# The models were trained using 2023 data and tested using 2022 data.
# The models were evaluated using:
# - R2 score,
# - mean absolute error,
# - mean bias error,
# - hourly accuracy,
# - and daily accuracy.

# %% [markdown]
# ## Results
# Add your results from `Analysis_Solar.ipynb` and `Analysis_Consumption.ipynb` here.
# Solar model result:
# - 5-minute R2:
# - 5-minute MAE:
# - hourly R2:
# - daily R2:
# Consumption model result:
# - 5-minute R2:
# - 5-minute MAE:
# - hourly R2:
# - daily R2:

# %% [markdown]
# ## Limitations
#
# The main limitations were:
# - The 2022 DEOP data starts in March; the weather data for that year is
#   cropped to the same window rather than used to fabricate solar or wind
#   generation for the unmonitored Jan-Feb period.
# - Missing solar and wind generation had to be reconstructed rather than
#   directly measured, using expected-generation and empirical wind-speed
#   curves respectively.
# - The model results depend on the quality of the cleaned and repaired data.
# - Battery and electrolyser simulation outputs exist under
#   `Data/Analysis/Simulations` and `Data/Analysis/Data_Tables`, but the
#   original simulation scripts were not recreated in this workflow. They are
#   a useful independent check for any surplus/excess-energy figures computed
#   from the models here.

# %% [markdown]
# ## Conclusion
#
# This project recreated the main data cleaning, feature engineering, and machine learning workflow.
# The workflow showed how raw energy and weather data can be converted into useful forecasting datasets.
# The solar model predicted PV generation using irradiance, time, and historical solar generation features.
# The consumption model predicted electricity demand using weather, calendar, lag, and rolling baseline features.
